# %% [markdown]
# # Short Introduction
# The analysis explores the candy power ranking dataset from FiveThirtyEight (for more detailed informations see https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/).
#
# This notebook provides initial exploratory analysis of the data to better visualize and understnad variables.

# %% [markdown]
# # Overview

# %% [markdown]
# First of all we load all needed packages.

# %%
# %run "./Libraries"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv')
df['competitorname'] = df.competitorname.apply(lambda l: l.replace('Õ', '\''))
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competitorname    85 non-null     object
#  1   chocolate         85 non-null     int64
#  2   fruity            85 non-null     int64
#  3   caramel           85 non-null     int64
#  4   peanutyalmondy    85 non-null     int64
#  5   nougat            85 non-null     int64
#  6   crispedricewafer  85 non-null     int64
#  7   hard              85 non-null     int64
#  8   bar               85 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64</div>

# %%
df['competitorname'] = df.competitorname.apply(lambda l: l.replace('Õ', '\''))
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
plt.figure(figsize=(8,19))
sns.barplot(x=df["winpercent"],y=df["competitorname"],order=df[["competitorname","winpercent"]].sort_values(by="winpercent",ascending=False).iloc[:,0],palette="PuRd_r")
plt.xlabel("Win percentage")
plt.ylabel("")
plt.title("Candy Ranking")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0.5, 1.0, &#39;Candy Ranking&#39;)</div>

# %% [markdown]
# The characteristics of the binary features (all features except for sugarpercent and pricepercent):

# %%
df[df.columns[1:-3]].agg(['sum','count'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>chocolate</th>
#       <th>fruity</th>
#       <th>caramel</th>
#       <th>peanutyalmondy</th>
#       <th>nougat</th>
#       <th>crispedricewafer</th>
#       <th>hard</th>
#       <th>bar</th>
#       <th>pluribus</th>
#     </tr>
# ...

# %% [markdown]
# The characteristics of the non-binary features sugarpercent and pricepercent:

# %%
df[['sugarpercent', 'pricepercent']].describe().T
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>sugarpercent</th>
# ...

# %% [markdown]
# ## Top Ten & Worst Ten

# %% [markdown]
# For a first impression we take a short look at the top ten:

# %%
df.sort_values('winpercent', ascending=False)[:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>competitorname</th>
#       <th>chocolate</th>
#       <th>fruity</th>
#       <th>caramel</th>
#       <th>peanutyalmondy</th>
#       <th>nougat</th>
#       <th>crispedricewafer</th>
#       <th>hard</th>
#       <th>bar</th>
# ...

# %% [markdown]
# and the worst ten:

# %%
df.sort_values('winpercent')[:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>competitorname</th>
#       <th>chocolate</th>
#       <th>fruity</th>
#       <th>caramel</th>
#       <th>peanutyalmondy</th>
#       <th>nougat</th>
#       <th>crispedricewafer</th>
#       <th>hard</th>
#       <th>bar</th>
# ...

# %% [markdown]
# We can see that chocolate and perhaps peanutyalmondy have a positive effect to winpercent. Additionaly fruity seems to have a negative impact.
#
# Now let us using statistical and machine learning methods for a more reliable analysis. Because nougat and crispedricewafer are rare we will omit them.

# %% [markdown]
# # Box Plot

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Histogram

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Correlation Matrics
#
# The correlation matrics contains every correlation coefficiant for every pair of features and target variable.

# %%
plt.figure(figsize=(10,10))
mask=np.zeros_like(df.corr(),dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(data=df.corr(),annot=True,square=True,mask=mask,cmap="GnBu",linewidths=1,linecolor="white")
plt.title("Candy characteristics correlation")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Text(0.5, 1.0, &#39;Candy characteristics correlation&#39;)</div>

# %% [markdown]
# Since the matrics is large and therefore a little bit confusing, here the top ten of correlations (positive and negative):

# %%
corr_df = pd.DataFrame([(f1, f2, df.corr()[f1].loc[f2]) for (f1, f2) in itertools.combinations(df.columns[1:].sort_values(), 2)],
             columns=['feature1', 'feature2', 'corr']).sort_values('corr')

corr_df = corr_df.iloc[(-corr_df['corr'].abs()).argsort()].reset_index(drop=True)
corr_df[:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature1</th>
#       <th>feature2</th>
#       <th>corr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>chocolate</td>
#       <td>fruity</td>
#       <td>-0.741721</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# And here the correlation coefficients for winpercent only:

# %%
corr_df[(corr_df.feature1 == 'winpercent') | (corr_df.feature2 == 'winpercent')]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature1</th>
#       <th>feature2</th>
#       <th>corr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>chocolate</td>
#       <td>winpercent</td>
#       <td>0.636517</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# We see that chocolate and winpercent have the largest correlation. Also bar and winpercent just as peanutyalmondy and winpercent have noticeable correlations. But we have to be careful because also chocolate and bar have a large correlation.

# %% [markdown]
# # Summary
#
# We cleansed the data for some anomolous characters and checked for outliers.  We then visualized the features to understand correlated variables and will further analyze these variables in the next notebook.
